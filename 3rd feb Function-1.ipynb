# %%
print("this is my print")
# Out:
# this is my print

# %%
l=[324,45,45,45]

# %%
len(l)
# Out:
# 4

# %%
type(l)
# Out:
# list

# %%
def test():
    pass

# %%
def test1():
    print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1()
# Out:
# this is my very very first function

# %%
test1() + "sudh"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 test1() + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
    return "this is my very first return"

# %%
test2()

# %%
test2() + "sudh"

# %%
def test3():

   return "sudh",23,345.56, [1,2,3,3]

# %%
test3()

# %%
a,b,c,d=test3()

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/2167009006.py in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
b

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/3235490055.py in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
d

# %%
a=1
b=4

# %%
a,b=1,4

# %%
def test4():
    a=5+6/7
    return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
    d=a+b/c
    return d

# %%
test5()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/379652043.py in <module>
# ----> 1 test5()
#
# TypeError: test5() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
    return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("sudh"," kumar")
# Out:
# 'sudh kumar'

# %%
test6([1,2,3,4,5],[4,5,6])
# Out:
# [1, 2, 3, 4, 5, 4, 5, 6]

# %%
l=[1,2,3,4,"sudh","kumar",[1,2,3,4,5,6]]

# %%
l1=[]
for i in l:
    if type(i)==int or type(i)==float:
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
def test7(l):
    l1=[]
    for i in l:
        if type(i)==int or type(i)==float:
            l1.append(i)
    return l1

# %%
test7(l)
# Out:
# [1, 2, 3, 4]

# %%
l
# Out:
# [1, 2, 3, 4, 'sudh', 'kumar', [1, 2, 3, 4, 5, 6]]

# %%
def test8(a):
    """this is myfunction to extaract numaric data from list"""
    l=[]
    for i in a:
        if type(i)==list:
            for j in i:
                l.append(j)
        else:
            if type(i)==int or type(i)==float:
                l.append(i)

    return l

# %%
test8(l)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5, 6]

# %%
l
# Out:
# [1, 2, 3, 4, 'sudh', 'kumar', [1, 2, 3, 4, 5, 6]]

# %%
test8()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27/4057327270.py in <module>
# ----> 1 test8()
#
# TypeError: test8() missing 1 required positional argument: 'a'

# %%
def test10(a,b):
    return a+b

# %%
def test11(*args):
    return args

# %%
test11()
# Out:
# ()

# %%
type(test11())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(test11())
#
# NameError: name 'test11' is not defined

# %%
def test12(*sudh):
    return sudh

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*arg,a):
    return arg,a

# %%
test13(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test13(1,2,3,4)
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4, a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d, a=23,b=1,):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}
